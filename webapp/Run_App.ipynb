# %% [markdown]
# # Run the Synthetix.ai Flask App
#
# This notebook allows you to run the unified Flask application directly from Jupyter.
#
# ### 1. Install Dependencies
# Make sure all required packages are installed in your current environment.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 2. Run the Unified Flask App
#
# This will start the server on **port 5000**.
#
# - **Local**: Access it at [http://localhost:5000](http://localhost:5000)
# - **Colab/Remote**: You may need to use a tool like `localtunnel` or `ngrok` to expose the port, or use the Jupyter proxy if available.

# %%
from app import app

if __name__ == '__main__':
    # Note: set debug=False if running in a persistent environment to avoid issues with the reloader
    app.run(host='0.0.0.0', port=5000, debug=False)
